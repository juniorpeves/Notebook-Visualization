# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('population_by_country_2020.csv')
Q1 =df[(df['Region'] == 'LATIN')  & (df['Med. Age'] > 0)]
Q1
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 7                 Argentina           45267449         0.93%      415097
# 9                     Aruba             106845         0.43%         452
# 13                  Bahamas             393893         0.97%        3762
# 16                 Barbados             287437         0.12%         350
# 19                   Belize             398845         1.86%        7275
# 23                  Bolivia           11700207         1.39%      159921
# 25                   Brazil          212821986         0.72%     1509890
# 35                    Chile           19144605         0.87%      164163
# 37                 Colombia           50976248         1.08%      543448
# 42               Costa Rica            5102158         0.92%       46557
# 44                     Cuba           11325391        -0.06%       -6867
# 49       Dominican Republic           10866667         1.01%      108952
# 50                  Ecuador           17688599         1.55%      269392
# 52              El Salvador            6491923         0.51%       32652
# 60            French Guiana             299958         2.70%        7850
# 70                  Grenada             112614         0.46%         520
# 71               Guadeloupe             400136         0.02%          68
# 73                Guatemala           17971382         1.90%      334096
# 76                   Guyana             787215         0.48%        3786
# 77                    Haiti           11426356         1.24%      139451
# 78                 Honduras            9931333         1.63%      158490
# 90                  Jamaica            2963429         0.44%       12888
# 114              Martinique             375213        -0.08%        -289
# 118                  Mexico          129166028         1.06%     1357224
# 132               Nicaragua            6638075         1.21%       79052
# 140                  Panama            4326296         1.61%       68328
# 142                Paraguay            7147553         1.25%       87902
# 143                    Peru           33050211         1.42%      461401
# 147             Puerto Rico            2846860        -2.47%      -72555
# 154             Saint Lucia             183774         0.46%         837
# 172                Suriname             587541         0.90%        5260
# 191                 Uruguay            3475842         0.35%       11996
# 194               Venezuela           28421581        -0.28%      -79889
#
#      Density (P/Km²)  Land Area (Km²)  Migrants (net)  Fert. Rate  Med. Age  \
# 7                 17          2736690          4800.0         2.3      32.0
# 9                593              180           201.0         1.9      41.0
# 13                39            10010          1000.0         1.8      32.0
# 16               668              430           -79.0         1.6      40.0
# 19                17            22810          1200.0         2.3      25.0
# 23                11          1083300         -9504.0         2.8      26.0
# 25                25          8358140         21200.0         1.7      33.0
# 35                26           743532        111708.0         1.7      35.0
# 37                46          1109500        204796.0         1.8      31.0
# 42               100            51060          4200.0         1.8      33.0
# 44               106           106440        -14400.0         1.6      42.0
# 49               225            48320        -30000.0         2.4      28.0
# 50                71           248360         36400.0         2.4      28.0
# 52               313            20720        -40539.0         2.1      28.0
# 60                 4            82200          1200.0         3.4      25.0
# 70               331              340          -200.0         2.1      32.0
# 71               237             1690         -1440.0         2.2      44.0
# 73               167           107160         -9215.0         2.9      23.0
# 76                 4           196850         -6000.0         2.5      27.0
# 77               414            27560        -35000.0         3.0      24.0
# 78                89           111890         -6800.0         2.5      24.0
# 90               273            10830        -11332.0         2.0      31.0
# 114              354             1060          -960.0         1.9      47.0
# 118               66          1943950        -60000.0         2.1      29.0
# 132               55           120340        -21272.0         2.4      26.0
# 140               58            74340         11200.0         2.5      30.0
# 142               18           397300        -16556.0         2.4      26.0
# 143               26          1280000         99069.0         2.3      31.0
# 147              323             8870        -97986.0         1.2      44.0
# 154              301              610             0.0         1.4      34.0
# 172                4           156000         -1000.0         2.4      29.0
# 191               20           175020         -3000.0         2.0      36.0
# 194               32           882050       -653249.0         2.3      30.0
#
#     Urban Pop % World Share Region
# 7           93%       0.58%  LATIN
# 9           44%       0.00%  LATIN
# 13          86%       0.01%  LATIN
# 16          31%       0.00%  LATIN
# 19          46%       0.01%  LATIN
# 23          69%       0.15%  LATIN
# 25          88%       2.73%  LATIN
# 35          85%       0.25%  LATIN
# 37          80%       0.65%  LATIN
# 42          80%       0.07%  LATIN
# 44          78%       0.15%  LATIN
# 49          85%       0.14%  LATIN
# 50          63%       0.23%  LATIN
# 52          73%       0.08%  LATIN
# 60          87%       0.00%  LATIN
# 70          35%       0.00%  LATIN
# 71          NaN       0.01%  LATIN
# 73          52%       0.23%  LATIN
# 76          27%       0.01%  LATIN
# 77          57%       0.15%  LATIN
# 78          57%       0.13%  LATIN
# 90          55%       0.04%  LATIN
# 114         92%       0.00%  LATIN
# 118         84%       1.65%  LATIN
# 132         57%       0.08%  LATIN
# 140         68%       0.06%  LATIN
# 142         62%       0.09%  LATIN
# 143         79%       0.42%  LATIN
# 147         NaN       0.04%  LATIN
# 154         19%       0.00%  LATIN
# 172         65%       0.01%  LATIN
# 191         96%       0.04%  LATIN
# 194         NaN       0.36%  LATIN

# %%
# libraries
import matplotlib.pyplot as plt
import numpy as np

x = (Q1['Country (or dependency)']).to_numpy()
y = (Q1['Med. Age']).to_numpy()
z = (Q1['Population (2020)']).to_numpy()
colors = np.random.rand(len(Q1['Country (or dependency)']))

# use the scatter function
plt.scatter(x, y, s=z/100000, alpha=0.5, c=colors)
plt.xticks(rotation=90)
plt.ylabel("Med. Age")
# show the graph
plt.show()
