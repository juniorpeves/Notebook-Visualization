# %% [markdown]
# # Visualización de los departamentos del Perú con Geopandas
#
#
# ## Introdución
# Geopandas necesita de un archivo geojson el cual contiene poligonos de los departamentos del pais. Necesitamos cargar el archivo geojson para empezar a graficar.
#
# Si buscas de otro pais, es recomendable que lo googlees como "geojson Argentina ... Brasil, Bolovia, etc." Mucha gente sube gratuitamente este tipo de contenido a GitHub.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import geopandas as gpd

# %% [markdown]
# Carga de Archivo Geojson que contiene polígonos de las regiones del Perú

# %% [markdown]
# ## Departamentos

# %%
url_geojson = "peru_departamental_simple.geojson"

# %%
region_geojson = gpd.read_file(url_geojson)
region_geojson.head()
# Out:
#     NOMBDEP  COUNT FIRST_IDDP     HECTARES  \
# 0  AMAZONAS     84         01  3930646.567
# 1    ANCASH    166         02  3596224.600
# 2  APURIMAC     80         03  2111415.170
# 3  AREQUIPA    109         04  6325588.935
# 4  AYACUCHO    111         05  4350381.783
#
#                                             geometry
# 0  POLYGON ((-77.75893 -6.96451, -77.84586 -6.976...
# 1  POLYGON ((-77.31749 -8.53015, -77.28903 -8.589...
# 2  POLYGON ((-72.47177 -14.66140, -72.57725 -14.6...
# 3  POLYGON ((-75.07333 -15.44294, -75.04965 -15.4...
# 4  POLYGON ((-74.34595 -12.17374, -74.32187 -12.2...

# %% [markdown]
# Visualización

# %%
ax = region_geojson.plot(figsize=(15,15))
plt.ylabel('Latitude')
plt.xlabel('Longitude')
plt.show()

# %%
ax = region_geojson.plot(figsize=(20,20),edgecolor=u'gray', cmap='Pastel1')
plt.ylabel('Latitude')
plt.xlabel('Longitude')
plt.show()

# %% [markdown]
# ## Provincias

# %%
url_geojson = "peru_provincial_simple.geojson"

provinces_geojson = gpd.read_file(url_geojson)
provinces_geojson.head()
# Out:
#    COUNT FIRST_IDPR       NOMBPROV    FIRST_NOMB LAST_DCTO LAST_LEY  \
# 0      9       0301        ABANCAY      APURIMAC       LEY      S/N
# 1      8       0902       ACOBAMBA  HUANCAVELICA       LEY     5292
# 2      7       0802        ACOMAYO         CUSCO       LEY      S/N
# 3      5       0202           AIJA        ANCASH       LEY     8188
# 4      6       1602  ALTO AMAZONAS        LORETO       LEY      S/N
#
#    FIRST_FECH  LAST_FECHA    MIN_SHAPE_          ha  \
# 0  28/12/1961  21/11/1893  3.458273e+05   345827.34
# 1  23/11/1925  23/11/1925  9.263674e+04    92636.74
# 2  11/11/1964  02/01/1857  9.328581e+04    93285.81
# 3  21/12/1907  05/03/1936  6.963963e+04    69639.63
# 4  08/09/1964  02/01/1857  1.917213e+06  1917212.66
#
#                                             geometry
# 0  POLYGON ((-72.77286 -13.44888, -72.74545 -13.4...
# 1  POLYGON ((-74.32362 -12.83251, -74.31945 -12.8...
# 2  POLYGON ((-71.51688 -13.96722, -71.44034 -14.1...
# 3  POLYGON ((-77.96140 -9.78024, -77.86786 -9.763...
# 4  POLYGON ((-76.28970 -3.69122, -76.24529 -3.751...

# %%
ax = provinces_geojson.plot(figsize=(20,20))
plt.ylabel('Latitude')
plt.xlabel('Longitude')
plt.show()

# %%
ax = provinces_geojson.plot(figsize=(20,20),edgecolor=u'gray', cmap='Pastel1')
plt.ylabel('Latitude')
plt.xlabel('Longitude')
plt.show()

# %% [markdown]
# Podemos pintar un departamento especifico de la siguiente manera.
#
# Ejemplo departamento **Cusco**

# %%
ax = provinces_geojson[provinces_geojson.FIRST_NOMB=='MADRE DE DIOS'].plot(figsize=(10,10),edgecolor=u'gray', cmap='Pastel1')
plt.ylabel('Latitude')
plt.xlabel('Longitude')
ax.axis('scaled')
plt.show()

# %% [markdown]
# ## Distritos

# %%
url_geojson = "peru_distrital_simple.geojson"

districts_geojson = gpd.read_file(url_geojson)
districts_geojson.head()
# Out:
#    OBJECTID  IDDIST IDDPTO IDPROV                              NOMBDIST  \
# 0         1  230110     23   2301  CORONEL GREGORIO ALBARRACIN LANCHIPA
# 1         2  230108     23   2301                              POCOLLAY
# 2         3  230103     23   2301                                CALANA
# 3         4  230101     23   2301                                 TACNA
# 4         5  230109     23   2301                                  SAMA
#
#   NOMBPROV NOMBDEP DCTO    LEY         FECHA         NOM_CAP  SHAPE_LENG  \
# 0    TACNA   TACNA  LEY  27415    02/02/2001  ALFONSO UGARTE    0.570510
# 1    TACNA   TACNA  LEY  13069    15/01/1959        POCOLLAY    0.883871
# 2    TACNA   TACNA  LEY    S/N    20/08/1872          CALANA    0.446736
# 3    TACNA   TACNA    -      -  EPOCA INDEP.           TACNA    2.758951
# 4    TACNA   TACNA    -      -  EPOCA INDEP.       LAS YARAS    1.515506
#
#    SHAPE_AREA  SHAPE_LE_1  SHAPE_AR_1  AREA_MINAM  \
# 0    0.016140    0.570195    0.015990    18834.14
# 1    0.022816    0.897169    0.022961    27073.52
# 2    0.009458    0.445963    0.009383    11063.99
# 3    0.209156    2.758123    0.209177   246365.27
# 4    0.096789    1.513660    0.096766   113953.51
#
#                                             geometry
# 0  POLYGON ((-70.14409 -18.09309, -70.17512 -18.1...
# 1  POLYGON ((-69.90467 -17.95829, -69.98287 -18.0...
# 2  POLYGON ((-70.09201 -17.98026, -70.17243 -18.0...
# 3  POLYGON ((-70.23500 -17.99231, -70.23710 -18.0...
# 4  POLYGON ((-70.42374 -17.88983, -70.51323 -17.9...

# %%
ax = districts_geojson.plot(figsize=(20,20))
plt.ylabel('Latitude')
plt.xlabel('Longitude')
plt.show()

# %%
ax = districts_geojson.plot(figsize=(20,20),edgecolor=u'gray', cmap='Pastel1')
plt.ylabel('Latitude')
plt.xlabel('Longitude')
plt.show()

# %% [markdown]
# Podemos seleccionar un departamento en especifico
#
# Ejemplo, **Cusco**.

# %%
ax = districts_geojson[districts_geojson.NOMBDEP=='MADRE DE DIOS'].plot(figsize=(10,10),edgecolor=u'gray', cmap='Pastel1')
plt.ylabel('Latitude')
plt.xlabel('Longitude')
ax.axis('scaled')
plt.show()

# %% [markdown]
# También podemos seleccionar un distrito en especifico.
# Ejemplo, **Calca** (Cusco).
#
# ```
# python
# print("Mi querido Calca, se encuentra en el Valle Sagrado de los Incas - Cusco Perú 😊")
# ```

# %%
ax = districts_geojson[districts_geojson.NOMBPROV=='TAMBOPATA'].plot(figsize=(10,10),edgecolor=u'gray', cmap='Pastel1')
plt.ylabel('Latitude')
plt.xlabel('Longitude')
ax.axis('scaled')
plt.show()

# %% [markdown]
# #### Archivos:
# - peru_distrital_simple.geojson
# - peru_provincial_simple.geojson
# - peru_departamental_simple.geojson

# %% [markdown]
# Copia no oficial, original de Noe Melo Locumber
# [Link](https://www.kaggle.com/noemelo/geopandas-mapa-del-peru/notebook)
